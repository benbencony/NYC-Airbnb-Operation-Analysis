# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('listings_final.csv')
# Out:
# G:\Users\lenovo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (43,87,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#              id                            listing_url       scrape_id  \
# 0         15509     https://www.airbnb.com/rooms/15509  20181103152857
# 1          2515      https://www.airbnb.com/rooms/2515  20181103152857
# 2          2539      https://www.airbnb.com/rooms/2539  20181103152857
# 3          2595      https://www.airbnb.com/rooms/2595  20181103152857
# 4         15729     https://www.airbnb.com/rooms/15729  20181103152857
# 5          3330      https://www.airbnb.com/rooms/3330  20181103152857
# 6         16326     https://www.airbnb.com/rooms/16326  20181103152857
# 7          3647      https://www.airbnb.com/rooms/3647  20181103152857
# 8          3831      https://www.airbnb.com/rooms/3831  20181103152857
# 9         16338     https://www.airbnb.com/rooms/16338  20181103152857
# 10         5022      https://www.airbnb.com/rooms/5022  20181103152857
# 11        16421     https://www.airbnb.com/rooms/16421  20181103152857
# ...

# %%
df=df.drop('listing_url',axis=1)
df=df.drop('scrape_id',axis=1)
df=df.drop('last_scraped',axis=1)
df=df.drop('summary',axis=1)
df=df.drop('space',axis=1)
df=df.drop('description',axis=1)
df=df.drop('experiences_offered',axis=1)
df=df.drop('neighborhood_overview',axis=1)
df=df.drop('notes',axis=1)
df=df.drop('transit',axis=1)
df=df.drop('access',axis=1)
df=df.drop('interaction',axis=1)
df=df.drop('house_rules',axis=1)
df=df.drop('thumbnail_url',axis=1)
df=df.drop('medium_url',axis=1)
df=df.drop('picture_url',axis=1)
df=df.drop('xl_picture_url',axis=1)

# %%
df=df.drop('host_name',axis=1)
df=df.drop('host_url',axis=1)
df=df.drop('host_about',axis=1)
df=df.drop('host_response_time',axis=1)
df=df.drop('host_response_rate',axis=1)
df=df.drop('host_acceptance_rate',axis=1)
df=df.drop('host_thumbnail_url',axis=1)
df=df.drop('host_picture_url',axis=1)
df=df.drop('host_verifications',axis=1)
df=df.drop('host_has_profile_pic',axis=1)
df=df.drop('host_identity_verified',axis=1)
df=df.drop('country_code',axis=1)
df=df.drop('country',axis=1)

# %%
df=df.drop('reviews_per_month',axis=1)
df=df.drop('require_guest_phone_verification',axis=1)
df=df.drop('require_guest_profile_picture',axis=1)
df=df.drop('requires_license',axis=1)
df=df.drop('license',axis=1)
df=df.drop('availability_30',axis=1)
df=df.drop('availability_60',axis=1)
df=df.drop('availability_90',axis=1)
df=df.drop('availability_365',axis=1)

# %%
df=df.drop('host_location',axis=1)
df=df.drop('city',axis=1)
df=df.drop('state',axis=1)

# %%
df=df.drop('jurisdiction_names',axis=1)

# %%
df
# Out:
#              id                                               name    host_id  \
# 0         15509                   Sleep at the CozySuite Sanctuary      59777
# 1          2515                   Stay at Chez Chic budget room #1       2758
# 2          2539                 Clean & quiet apt home by the park       2787
# 3          2595                              Skylit Midtown Castle       2845
# 4         15729                                      Village Green      61531
# 5          3330                 ++ Brooklyn Penthouse Guestroom ++       4177
# 6         16326         Comfortable 4-bedroom apt in family house.      63588
# 7          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 8          3831                    Cozy Entire Floor of Brownstone       4869
# 9         16338  Double Room w Private Deck Clinton Hill Best Area      63613
# 10         5022   Entire Apt: Spacious Studio/Loft by central park       7192
# ...

# %%
df1=df.dropna()

# %%
df1=df1.dropna(axis=1, how='any')

# %%
list(df1.columns)
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_since',
#  'host_is_superhost',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'zipcode',
#  'market',
#  'smart_location',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'calendar_updated',
#  'has_availability',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
# ...

# %%
len(list(df1.columns))
# Out:
# 53

# %%
df['price'] = df['price'].str.replace("[$, ]", "").astype("float")

# %%
df['price']
# Out:
# 0         59.0
# 1         59.0
# 2        149.0
# 3        225.0
# 4         89.0
# 5         70.0
# 6        200.0
# 7        150.0
# 8         89.0
# 9         55.0
# 10        80.0
# 11        52.0
# 12       225.0
# 13        80.0
# 14       375.0
# 15        79.0
# 16       185.0
# 17        60.0
# 18       329.0
# 19       225.0
# 20       129.0
# 21        79.0
# 22        59.0
# 23        79.0
# 24        51.0
# 25       126.0
# 26        69.0
# 27       180.0
# 28       120.0
# 29       180.0
#          ...
# 50938    138.0
# 50939     80.0
# 50940     50.0
# 50941    150.0
# 50942    151.0
# 50943    100.0
# 50944    250.0
# 50945    150.0
# 50946     79.0
# 50947     39.0
# 50948     45.0
# 50949    175.0
# 50950    199.0
# 50951    109.0
# 50952     81.0
# 50953    200.0
# 50954    105.0
# 50955    199.0
# 50956    120.0
# 50957     44.0
# 50958    150.0
# 50959     45.0
# 50960     62.0
# 50961     60.0
# 50962     60.0
# 50963    100.0
# 50964    110.0
# ...

# %%
df['price'].hist(bins=50,range=(0,1300))
plt.ylabel('Count')
plt.xlabel('Listing price($)')
plt.title('Distribution of listing prices')
# Out:
# Text(0.5,1,'Distribution of listing prices')

# %%
df['price'].hist(bins=50,range=(0,600))
plt.ylabel('Count')
plt.xlabel('Listing price($)')
plt.title('Distribution of listing prices')
# Out:
# Text(0.5,1,'Distribution of listing prices')

# %%
df.pivot(columns = 'bedrooms',values = 'price').plot.hist(stacked = True,bins=100,range=(0,600))
plt.xlabel('Listing price($)')
# Out:
# Text(0.5,0,'Listing price($)')

# %%
df.pivot(columns = 'accommodates',values = 'price').plot.hist(stacked = True,bins=100,range=(0,600))
plt.xlabel('Listing price($)')
# Out:
# Text(0.5,0,'Listing price($)')

# %%
plt.scatter(df['price'],df['bedrooms'])
plt.ylabel('bedrooms')
plt.xlabel('Listing price($)')
plt.title('No. of bedrooms vs price')
# Out:
# Text(0.5,1,'No. of bedrooms vs price')

# %%
plt.scatter(df['price'],df['beds'])
plt.ylabel('beds')
plt.xlabel('Listing price($)')
plt.title('No. of beds vs price')
# Out:
# Text(0.5,1,'No. of beds vs price')

# %%
features = list(df.columns)

mask = np.zeros_like(df[features].corr(), dtype=np.bool) 
mask[np.triu_indices_from(mask)] = True 

f, ax = plt.subplots(figsize=(16, 12))
plt.title('Pearson Correlation Matrix',fontsize=25)

sns.heatmap(df[features].corr().round(2),linewidths=0.25,vmax=1.0,square=True,cmap="YlGnBu", 
            linecolor='w',annot=True,mask=mask,cbar_kws={"shrink": .75})

# %%
# def dollar(df,x):
#     temp=df['price'].loc[x]
#     temp=temp[1:]
#     df['price'].loc[x]=temp
#     return df['price'].loc[x]

# %%
# df.apply(lambda x: dollar(df, x ))

# %%
# df['price']=df['price'].apply(lambda x: df['price'][x][1:])

# %%
cols = ['review_scores_rating','accommodates','bathrooms','bedrooms','beds','price']

# %%
df1=df[cols].dropna(axis=0, how='any')

# %%
df1
# Out:
#        review_scores_rating  accommodates  bathrooms  bedrooms  beds  price
# 1                      93.0             3        1.0       1.0   3.0   59.0
# 2                      98.0             4        1.0       1.0   3.0  149.0
# 3                      95.0             2        1.0       0.0   1.0  225.0
# 4                      79.0             4        1.0       1.0   1.0   89.0
# 5                      98.0             2        1.0       1.0   1.0   70.0
# 6                      99.0             8        2.0       4.0   4.0  200.0
# 8                      91.0             3        1.0       1.0   3.0   89.0
# 9                      92.0             2        1.0       1.0   2.0   55.0
# 11                     89.0             1        1.0       1.0   1.0   52.0
# 12                    100.0             4        2.0       2.0   3.0  225.0
# 13                     95.0             2        1.0       1.0   1.0   80.0
# ...

# %%
sns.set(style = 'whitegrid',context = 'notebook')
sns.pairplot(df1)
plt.show()

# %%
sns.set(style = 'whitegrid',context = 'notebook')
sns.pairplot(df1)
plt.show()

# %%
len(df1)
# Out:
# 39113

# %%
df2=df.sample(n=20000)

# %%
import folium
import folium.plugins as plugins
import numpy as np


# prepare latitude and longitude data per trip per hour
data=list()

data.append([[df2.iloc[j]['latitude'],df2.iloc[j]['longitude']]for j in range(len(df2))])

weight = 1  # default value
for time_entry in data:
    for row in time_entry:
        row.append(weight)

# %%
m = folium.Map([40.7204, -73.9280], tiles='stamentoner', zoom_start=12)

hm = plugins.HeatMapWithTime(data)

hm.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_since', 'host_is_superhost',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'street', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'zipcode',
#        'market', 'smart_location', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'calendar_last_scraped', 'number_of_reviews', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
# ...

# %%
type(df['maximum_nights'][0])

# %%
df['maximum_nights'].min()

# %%
df['maximum_nights']

# %%
df['maximum_nights'].astype('int')

# %%
df['maximum_nights'].hist(bins=50,range=(0,1000))
plt.ylabel('Count')
plt.xlabel('maximum_nights')
plt.title('Distribution of maximum_nights')

# %%
len(df)

# %%
df_e=pd.read_csv('listings_final.csv')
# Out:
# G:\Users\lenovo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (43,87,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_e=df_e[df_e['room_type']=='Entire home/apt']

# %%
len(df_e)
# Out:
# 26593

# %%
df_e['availability_365'].hist(bins=50,range=(0,400))

# %%
df_e['availability_365'].hist(bins=50,range=(1,365))
plt.title('Number of houses in each length of available day in a year')
# Out:
# Text(0.5,1,'Number of houses in each length of available day in a year')
